# %%
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x =  df.drop('Profit', axis=1)

# %%
x
# Out:
#     Marketing Spend  Administration  Transport     Area
# 0         114523.61       136897.80  471784.10    Dhaka
# 1         162597.70       151377.59  443898.53      Ctg
# 2         153441.51       101145.55  407934.54  Rangpur
# 3         144372.41       118671.85  383199.62    Dhaka
# 4         142107.34        91391.77  366168.42  Rangpur
# 5         131876.90        99814.71  362861.36    Dhaka
# 6         134615.46       147198.87  127716.82      Ctg
# 7         130298.13       145530.06  323876.68  Rangpur
# 8         120542.52       148718.95  311613.29    Dhaka
# 9         123334.88       108679.17  304981.62      Ctg
# 10        101913.08       110594.11  229160.95  Rangpur
# 11        100671.96        91790.61  249744.55      Ctg
# 12         93863.75       127320.38  249839.44  Rangpur
# 13         91992.39       135495.07  252664.93      Ctg
# 14        119943.24       156547.42  256512.92  Rangpur
# 15        165349.20       122616.84  261776.23    Dhaka
# ...

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %% [markdown]
# # Measure of Central Tendency

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df[19:20]
# Out:
#     Marketing Spend  Administration  Transport   Area     Profit
# 19          86419.7       153514.11        NaN  Dhaka  122776.86

# %%
df.Transport.mean() #not for outlier
# Out:
# 215331.7324489796

# %%
df.Transport.median() #for outliers
# Out:
# 214634.81

# %%
df.Transport.max()
# Out:
# 471784.1

# %%
df.Transport.min()
# Out:
# 0.0

# %%
df.Transport = df.Transport.fillna(df.Transport.mean())

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df[19:20]
# Out:
#     Marketing Spend  Administration      Transport   Area     Profit
# 19          86419.7       153514.11  215331.732449  Dhaka  122776.86

# %% [markdown]
# # Label Encoder

# %%
def label_encoder(df, col):
    label_map = {}
    encoded_value = []
    
    for instance in df[col]:
        if instance not in label_map:
            label_map[instance] = len(label_map)
        encoded_value.append(label_map[instance])
    return encoded_value, label_map

encoded_value, label_map = label_encoder(x, 'Area')
x.Area = encoded_value

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport  Area
# 0        114523.61       136897.80  471784.10     0
# 1        162597.70       151377.59  443898.53     1
# 2        153441.51       101145.55  407934.54     2
# 3        144372.41       118671.85  383199.62     0
# 4        142107.34        91391.77  366168.42     2

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1.Area = le.fit_transform(df[['Area']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # Using For Loop

# %%
#assignment

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   1.0  192261.83
# 1        162597.70       151377.59  443898.53   0.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   1.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94

# %%
label_encoding_=df.drop('Profit', axis=1)

# %%
label_encoding_.head()
# Out:
#    Marketing Spend  Administration  Transport  Area
# 0        114523.61       136897.80  471784.10   1.0
# 1        162597.70       151377.59  443898.53   0.0
# 2        153441.51       101145.55  407934.54   2.0
# 3        144372.41       118671.85  383199.62   1.0
# 4        142107.34        91391.77  366168.42   2.0

# %%
data_type_value = label_encoding_.dtypes

# %%
data_type_value
# Out:
# Marketing Spend    float64
# Administration     float64
# Transport          float64
# Area               float64
# dtype: object

# %%
for i in range(len(data_type_value)):
    if data_type_value.iloc[i] == 'object':
        column_name = data_type_value.index[i]
        label_encoding_[column_name] = le.fit_transform(label_encoding_[column_name])

# %%
label_encoding_.head()
# Out:
#    Marketing Spend  Administration  Transport  Area
# 0        114523.61       136897.80  471784.10   1.0
# 1        162597.70       151377.59  443898.53   0.0
# 2        153441.51       101145.55  407934.54   2.0
# 3        144372.41       118671.85  383199.62   1.0
# 4        142107.34        91391.77  366168.42   2.0

# %%
df = pd.read_csv('supershops.csv') 
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # One Hot Encoder

# %%
df2 = df.copy()

# %%
pd.get_dummies(df2, prefix='area', drop_first=True).head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %%
#For Loop

# %%
one_hot_encoder_t = df.drop('Profit', axis=1)

# %%
one_hot_encoder_t.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
data_type_value2 = one_hot_encoder_t.dtypes

# %%
data_type_value2
# Out:
# Marketing Spend    float64
# Administration     float64
# Transport          float64
# Area                object
# dtype: object

# %%
for i in range(len(data_type_value2)):
    if data_type_value2.iloc[i] == 'object':
        column_name = data_type_value2.index[i]
        one_hot_encoder_t = pd.get_dummies(one_hot_encoder_t, columns=[column_name])

# %%
one_hot_encoder_t.head()
# Out:
#    Marketing Spend  Administration  Transport  Area_Ctg  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10     False        True
# 1        162597.70       151377.59  443898.53      True       False
# 2        153441.51       101145.55  407934.54     False       False
# 3        144372.41       118671.85  383199.62     False        True
# 4        142107.34        91391.77  366168.42     False       False
#
#    Area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # ORDINAL

# %%
df2.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal = OrdinalEncoder(categories = [['Dhaka', 'Ctg', 'Rangpur']])

# %%
df2.Area = ordinal.fit_transform(df2[['Area']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   0.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   0.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94

# %%
#For Loop

# %%
new_o=df.drop('Profit', axis=1)

# %%
new_o.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
for i in range(len(data_type_value3)):
    if data_type_value3.iloc[i] == 'object':
        column_name = data_type_value3.index[i]
        ordinal = OrdinalEncoder()
        new_o[column_name] = ordinal.fit_transform(new_o[[column_name]])

# %%
new_o.head()
# Out:
#    Marketing Spend  Administration  Transport  Area
# 0        114523.61       136897.80  471784.10   1.0
# 1        162597.70       151377.59  443898.53   0.0
# 2        153441.51       101145.55  407934.54   2.0
# 3        144372.41       118671.85  383199.62   1.0
# 4        142107.34        91391.77  366168.42   2.0
